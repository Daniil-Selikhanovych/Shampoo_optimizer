# %% [markdown]
# # Results
#
# In this notebook we present the final results of our work done in parallel in different notebooks.

# %%
import matplotlib.pyplot as plt

# %%
shampoo_1_e_4 = [2.172, 2.099, 2.060, 2.040, 1.924, 1.863, 1.831, 1.612, 1.574, 
     1.570, 1.568, 1.567, 1.565, 1.564, 1.564, 1.563, 1.562, 1.562, 1.561, 1.541]
shampoo_1_e_3 = [2.2700458, 2.2646148, 2.2647016, 2.26475,   2.2643468, 2.2641087, 2.149717,
 2.0826297, 2.0788326, 2.0771234, 2.0758808, 2.0751462, 2.0742776, 2.0733829,
 2.0730412, 2.072522,  2.0716708, 2.0712104, 2.0703914, 2.0699394]
shampoo_1_e_5 = [2.2387447, 2.1386147, 2.1050484, 2.0858123, 2.072684, 2.0626757, 2.0546875,
 2.048197, 2.0428867, 2.0385277, 2.0348425, 2.0316374, 2.0287993, 2.0262609,
 2.0239742, 2.0218985, 2.0200088, 2.0182874, 2.0166981, 2.015202 ]

# %%
plt.plot(shampoo_1_e_4, label = r"$lr = 10^{-4}$")
plt.plot(shampoo_1_e_3, label = r"$lr = 10^{-3}$")
plt.plot(shampoo_1_e_5, label = r"$lr = 10^{-5}$")
plt.grid(True) 
plt.xlabel('Epoch')
plt.ylabel("Loss")
plt.title(r'MNIST, Shampoo, tuning lr, $\varepsilon=10^{-4}$')
plt.legend()
plt.savefig('mnist_shampoo_lr.pdf')
plt.show()

# %%
shampoo_eps_1_e_3 = [1.9421835, 1.8399898, 1.8239046, 1.8168437, 1.8123877, 1.8091985, 1.8067957,
 1.8049272, 1.8034164, 1.8021604, 1.8010869, 1.800131,  1.799256,  1.7984507,
 1.7976927, 1.7969885, 1.7963359, 1.7957386, 1.7951891, 1.7946745]
shampoo_eps_1_e_5 = [1.9535859, 1.9010646, 1.8942442, 1.8906717, 1.8882418, 1.8591388, 1.8213507,
 1.8130248, 1.8089517, 1.80649, 1.8046523, 1.8031514, 1.8018868, 1.80078,
 1.7997972, 1.7989308, 1.7981664, 1.7974871, 1.7968667, 1.7962881]

# %%
plt.plot(shampoo_1_e_4, label = r"$\varepsilon = 10^{-4}$")
plt.plot(shampoo_eps_1_e_3, label = r"$\varepsilon = 10^{-3}$")
plt.plot(shampoo_eps_1_e_5, label = r"$\varepsilon = 10^{-5}$")
plt.grid(True) 
plt.xlabel('Epoch')
plt.ylabel("Loss")
plt.title(r'MNIST, Shampoo, tuning $\varepsilon$, $lr=10^{-4}$')
plt.legend()
plt.savefig('mnist_shampoo_eps.pdf')
plt.show()

# %%
shampoo_alpha_04 = [1.9321883, 1.8398277, 1.8224914, 1.8147941, 1.8096428, 1.8058493, 1.802955,
 1.8006934, 1.7988826, 1.7973859, 1.7960569, 1.7948228, 1.7937026, 1.7926776,
 1.7917578, 1.790942,  1.7902251, 1.7895894, 1.7890034, 1.7884506]
shampoo_alpha_06 = [2.0288804, 1.9752924, 1.9718345, 1.9515626, 1.885892,  1.8805844, 1.8786455,
 1.8773856, 1.8646451, 1.8000435, 1.7631915, 1.7185588, 1.7098085, 1.706121,
 1.7038869, 1.7022145, 1.7008101, 1.6996123, 1.6985755, 1.6976639]

# %%
plt.plot(shampoo_1_e_4, label = r"$\alpha = -0.25$")
plt.plot(shampoo_alpha_04, label = r"$\alpha = -0.2$")
plt.plot(shampoo_alpha_06, label = r"$\alpha = -0.3$")
plt.grid(True) 
plt.xlabel('Epoch')
plt.ylabel("Loss")
plt.title(r'MNIST, Shampoo, tuning $\alpha$, $lr=\varepsilon=10^{-4}$')
plt.legend()
plt.savefig('mnist_shampoo_alpha.pdf')
plt.show()

# %%
shampoo_1_e_4 = [2.172, 2.099, 2.060, 2.040, 1.924, 1.863, 1.831, 1.612, 1.574, 
     1.570, 1.568, 1.567, 1.565, 1.564, 1.564, 1.563, 1.562, 1.562, 1.561, 1.541]
adagrad_best = [2.159028,  2.1538925, 2.0939674, 1.9435356, 1.7837645, 1.7737274, 1.768616,
 1.7345455, 1.5734048, 1.5530177, 1.4775485, 1.4725941, 1.4705727, 1.4688113,
 1.4681926, 1.4672424, 1.466587,  1.4661719, 1.4659775, 1.4658241]
sgd_best = [1.9849198, 1.9353315, 1.8485464, 1.7639918, 1.6820042, 1.6750131, 1.67201,
 1.6696649, 1.668468,  1.666991,  1.5877107, 1.57015,   1.5482835, 1.4798003,
 1.4751656, 1.472733,  1.4714022, 1.4702785, 1.4693816, 1.4685464]
adam_best = [1.8145335, 1.690591,  1.6748366, 1.5842448, 1.577013,  1.573816,  1.5028594,
 1.4750677, 1.4731829, 1.4724473, 1.4711263, 1.4701109, 1.4693774, 1.4688377,
 1.4680884, 1.4680526, 1.4671156, 1.4672885, 1.4667993, 1.4663223]

# %%
plt.plot(shampoo_1_e_4, label = r"Shampoo")
plt.plot(adagrad_best, label = r"AdaGrad")
plt.plot(sgd_best, label = r"SGD")
plt.plot(adam_best, label = r"Adam")
plt.grid(True) 
plt.xlabel('Epoch')
plt.ylabel("Loss")
plt.title(r'MNIST, best optimizers')
plt.legend()
plt.savefig('mnist_best.pdf')
plt.show()

# %%
shampoo_cifar = [1.9401267,    1.8573929,    1.8198062,    1.8007333,    1.7936852,    1.7872975,    1.7808069,    
                 1.7777971,   
    1.7732044,    1.7710292,    1.7703147,    1.7699295,    1.7315373,    1.7002659,    1.6940337,    1.6909679,    
    1.6893677,    1.688624,    1.6881554,    1.6877893,    1.68754,    1.6870207,    1.6843606,    1.682654,  
    1.6823361,    1.6821555,    1.6820284,    1.6818712,    1.6817503,    1.6816367,    1.6815271,    1.6653703,  
    1.6236593,    1.6183072,    1.6167752,    1.614313,    1.6130122,    1.6124817,
    1.6112641,    1.6091008,    1.6088828,    1.6087587,    1.608667,    1.608594,    1.6085397,    1.608494,  
    1.608454,    1.6084183,    1.6083881,  
    1.6082424,    1.6074466,    1.6072608,    1.6071901,    1.6071467,    1.6071148,    1.6070901,    1.6070706,  
    1.6070538,    1.6070393,    1.6070267,    1.6070147,    1.6070045,    1.6069943,    1.6069862,   
    1.6069793,    1.6069711,
    1.6069628,    1.6069574,    1.6069527,    1.6069478,    1.6069436,    1.6069369,    1.6069307,    1.6069257,   
    1.6069221,    1.6069175,    1.6069142,    1.6069111,    1.6069076,    1.6069044,    1.6069006]  
adam_cifar = [2.046547,   1.9036598,   1.7916018,   1.7049781,   1.6311115,   1.6051077,
              1.5962576,   1.5869279,   1.5766717,   1.5750949,   1.5722988,
              1.5718685,   1.5717257,   1.5629296,   1.5563856,   1.5524596,   1.5394045,   1.5377499,
              1.5349493,   1.5347236,   1.5323198,   1.5309515,   1.5285783,
              1.5278116,   1.527072,   1.5235026,   1.523693,   1.5181409,   1.5131787,   1.5146421,
              1.5131036,   1.5147059,   1.5110253,   1.5081438,   1.5073589,   1.5074047,
              1.5071476,   1.506803,   1.5067718,   1.5066997,   1.5066704,   1.5061399,   1.5195293,
              1.5107828,   1.5071923,   1.50607,   1.5086621,   1.5048963,   1.5047408,   1.5046976,   1.5046759 ]
adagrad_cifar = [2.330, 2.331, 2.331, 2.136, 1.855, 1.747, 1.707, 1.662, 1.632, 1.626, 1.624, 1.621, 
                 1.619, 1.617, 1.617, 1.616, 1.616, 1.616, 1.616, 1.615, 1.612, 1.610, 1.609]
a = len(adagrad_cifar)
print(a)
adagrad_cifar += (51 - a)*[1.608]
# Out:
# 23

# %%
plt.plot(shampoo_cifar[:51], label = r"Shampoo")
plt.plot(adagrad_cifar, label = r"AdaGrad")
plt.plot(adam_cifar, label = r"Adam")
plt.grid(True) 
plt.xlabel('Epoch')
plt.ylabel("Loss")
plt.title(r'CIFAR10, best optimizers')
plt.legend()
plt.savefig('cifar_best.pdf')
plt.show()
